# %% [markdown]
# # Creating Mock Data

# %% [markdown]
# In the case you have a data model but no data, it can be useful to be able to generate some data for your model.
# There are several use cases for this
#
# * In the design phase, you want to quickly try out your current data model iteration with some data.
# * You need data for testing the data model.
# * Load testing of a data model.

# %% [markdown]
# `pygen` comes with a `MockGenerator`. Reference for this you can find [here](../api/utils_mock_generator.html), this is a practical guide to the usage of this module.

# %% [markdown]
# ## Generate Default Mock Data

# %%
from cognite.pygen.utils import MockGenerator, load_cognite_client_from_toml

# %%
client = load_cognite_client_from_toml()

# %% [markdown]
# In this example, we will use the `WindMill` data model as an example.
#
# Lets instantiate the `MockGenerator`, we do this by passing the data model along with the instance space we want to use for the
# generated data. In addition, we need an instantiated `CogniteClient` to fetch the data model.

# %%
generator = MockGenerator.from_data_model(("power-models", "Windmill", "1"), instance_space="sp_sandbox", client=client, seed=42)

# %%
generator
# Out:
# MockGenerator(view_count=11, instance_space=sp_sandbox, default_config=True, seed=42)

# %% [markdown]
# The `MockGenerator` has one method `generate_mock_data` which will generate the mock data using the default settings.

# %%
mock_data = generator.generate_mock_data()

# %% [markdown]
# ## Inspect Generated Mock Data

# %%
mock_data
# Out:
# MockData([ViewMockData(view_id=ViewId(space='power-models', external_id='Blade', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='blade_92349') at 0x195ac603400>, <NodeApply(space='sp_sandbox', external_id='blade_9116') at 0x195ac6034f0>, <NodeApply(space='sp_sandbox', external_id='blade_6006') at 0x195ac6035e0>, <NodeApply(space='sp_sandbox', external_id='blade_86673') at 0x195ac6036d0>, <NodeApply(space='sp_sandbox', external_id='blade_29871') at 0x195ac6037c0>], edge=[<EdgeApply(space='sp_sandbox', external_id='blade_92349:sensorposition_69352') at 0x195ac61e6a0>, <EdgeApply(space='sp_sandbox', external_id='blade_92349:sensorposition_32953') at 0x195ac61e790>, <EdgeApply(space='sp_sandbox', external_id='blade_92349:sensorposition_1504') at 0x195ac5fae50>, <EdgeApply(space='sp_sandbox', external_id='blade_9116:sensorposition_69352') at 0x195ac61e730>, <EdgeApply(space='sp_sandbox', external_id='blade_9116:sensorposition_72512') at 0x195ac61e820>, <EdgeApply(space='sp_sandbox', external_id='blade_9116:sensorposition_1504') at 0x195ac61e880>, <EdgeApply(space='sp_sandbox', external_id='blade_6006:sensorposition_69352') at 0x195ac624400>, <EdgeApply(space='sp_sandbox', external_id='blade_6006:sensorposition_72512') at 0x195ac624310>, <EdgeApply(space='sp_sandbox', external_id='blade_86673:sensorposition_1504') at 0x195ac624370>, <EdgeApply(space='sp_sandbox', external_id='blade_86673:sensorposition_72512') at 0x195ac624580>, <EdgeApply(space='sp_sandbox', external_id='blade_29871:sensorposition_72512') at 0x195ac624520>, <EdgeApply(space='sp_sandbox', external_id='blade_29871:sensorposition_32953') at 0x195ac624760>, <EdgeApply(space='sp_sandbox', external_id='blade_29871:sensorposition_69352') at 0x195ac6246d0>], timeseries=[], sequence=[], file=[]),
#           ViewMockData(view_id=ViewId(space='power-models', external_id='SensorPosition', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='sensorposition_69352') at 0x195ac603ac0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_32953') at 0x195ac60b550>, <NodeApply(space='sp_sandbox', external_id='sensorposition_72512') at 0x195ac60b640>, <NodeApply(space='sp_sandbox', external_id='sensorposition_1504') at 0x195ac60b730>, <NodeApply(space='sp_sandbox', external_id='sensorposition_89166') at 0x195ac60b820>], edge=[], timeseries=[<cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603DC0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603DF0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603E20>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603E50>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603EB0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603EE0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603F10>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603F40>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603FA0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC603FD0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B040>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B070>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B0D0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B100>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B130>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B160>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B1C0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B1F0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B220>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B250>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B2B0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B2E0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B310>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B340>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B3A0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B3D0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B400>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B430>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B490>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B4C0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B4F0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC60B520>], sequence=[], file=[]),
#           ViewMockData(view_id=ViewId(space='power-models', external_id='Windmill', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='windmill_94811') at 0x195ac603b80>, <NodeApply(space='sp_sandbox', external_id='windmill_74847') at 0x195ac603f70>, <NodeApply(space='sp_sandbox', external_id='windmill_75525') at 0x195ac603d00>, <NodeApply(space='sp_sandbox', external_id='windmill_61953') at 0x195ac60b9d0>, <NodeApply(space='sp_sandbox', external_id='windmill_31850') at 0x195ac60bd60>], edge=[<EdgeApply(space='sp_sandbox', external_id='windmill_94811:blade_86673') at 0x195ac624a90>, <EdgeApply(space='sp_sandbox', external_id='windmill_94811
version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='generator_29831') at 0x195ac61b580>, <NodeApply(space='sp_sandbox', external_id='generator_29219') at 0x195ac61b340>, <NodeApply(space='sp_sandbox', external_id='generator_3101') at 0x195ac61b3d0>, <NodeApply(space='sp_sandbox', external_id='generator_86511') at 0x195ac61e310>, <NodeApply(space='sp_sandbox', external_id='generator_25313') at 0x195ac61e400>], edge=[], timeseries=[<cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E100>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E130>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E160>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E190>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E1F0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E220>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E250>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E280>], sequence=[], file=[]),
#           ViewMockData(view_id=ViewId(space='power-models', external_id='PowerInverter', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='powerinverter_50488') at 0x195ac61be50>, <NodeApply(space='sp_sandbox', external_id='powerinverter_75574') at 0x195ac61e040>, <NodeApply(space='sp_sandbox', external_id='powerinverter_24914') at 0x195ac61eb80>, <NodeApply(space='sp_sandbox', external_id='powerinverter_33386') at 0x195ac61ed30>, <NodeApply(space='sp_sandbox', external_id='powerinverter_5817') at 0x195ac61ee20>], edge=[], timeseries=[<cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61E9D0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EA00>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EA30>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EA60>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EAC0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EAF0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EB20>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EB50>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EBB0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EBE0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EC10>, <cognite.client.data_classes.time_series.TimeSeries object at 0x00000195AC61EC40>], sequence=[], file=[])])

# %%
mock_data.nodes.to_pandas().head()
# Out:
#   instance_type       space  external_id  \
# 0          node  sp_sandbox  blade_92349
# 1          node  sp_sandbox   blade_9116
# 2          node  sp_sandbox   blade_6006
# 3          node  sp_sandbox  blade_86673
# 4          node  sp_sandbox  blade_29871
#
#                                              sources
# 0  [{'properties': {'name': 'KriXref', 'is_damage...
# 1  [{'properties': {'name': 'evblAbk', 'is_damage...
# 2  [{'properties': {'name': 'HbolMJU', 'is_damage...
# 3  [{'properties': {'name': None, 'is_damaged': T...
# 4  [{'properties': {'name': 'HClEQaP', 'is_damage...

# %% [markdown]
# The mock data has a few convenience methods to make it easy to use the data. We can deploy and clean it, as well as dump it as yaml.

# %%
mock_data.deploy(client)
# Out:
# Created 55 nodes and 28 edges
# Created/Updated 136 timeseries

# %%
mock_data.clean(client, delete_space=True)
# Out:
# Deleted 55 nodes and 28 edges
# Deleted 136 timeseries
# Deleted space sp_sandbox

# %% [markdown]
# ## Control Amount of Mock Data

# %% [markdown]
# You can also control how the data is generated by providing one or more configs.
#
# The easiest is to probide a default config that will be used for all views, but you can also have one config per view.

# %%
from cognite.pygen.utils.mock_generator import ViewMockConfig, GeneratorFunction, IDGeneratorFunction, DataType

# %% [markdown]
# If we want to generate more nodes and edges we can set the default config.

# %%
views = client.data_modeling.data_models.retrieve(("power-models", "Windmill", "1"), inline_views=True).latest_version().views

# %%
new_generator = MockGenerator(views, instance_space="sp_sandbox", default_config=
                              ViewMockConfig(node_count=100, max_edge_per_type=3, null_values=0.1))

# %%
more_data = new_generator.generate_mock_data()

# %%
more_data
# Out:
# MockData([ViewMockData(view_id=ViewId(space='power-models', external_id='Blade', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='blade_92480') at 0x23d7366c190>, <NodeApply(space='sp_sandbox', external_id='blade_7098') at 0x23d7366b5b0>, <NodeApply(space='sp_sandbox', external_id='blade_8343') at 0x23d7366b700>, <NodeApply(space='sp_sandbox', external_id='blade_35425') at 0x23d7366b1f0>, <NodeApply(space='sp_sandbox', external_id='blade_76804') at 0x23d7366b280>, <NodeApply(space='sp_sandbox', external_id='blade_41247') at 0x23d7366b250>, <NodeApply(space='sp_sandbox', external_id='blade_81601') at 0x23d73d44100>, <NodeApply(space='sp_sandbox', external_id='blade_78752') at 0x23d73d44280>, <
...
#           ViewMockData(view_id=ViewId(space='power-models', external_id='SensorPosition', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='sensorposition_90910') at 0x23d73eedd60>, <NodeApply(space='sp_sandbox', external_id='sensorposition_47401') at 0x23d742379a0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_95593') at 0x23d74237a90>, <NodeApply(space='sp_sandbox', external_id='sensorposition_87712') at 0x23d74237b80>, <NodeApply(space='sp_sandbox', external_id='sensorposition_86692') at 0x23d74237c70>, <NodeApply(space='sp_sandbox', external_id='sensorposition_75218') at 0x23d74237d60>, <NodeApply(space='sp_sandbox', external_id='sensorposition_6394') at 0x23d74237e50>, <NodeApply(space='sp_sandbox', external_id='sensorposition_88809') at 0x23d74237f40>, <NodeApply(space='sp_sandbox', external_id='sensorposition_36821') at 0x23d7423f070>, <NodeApply(space='sp_sandbox', external_id='sensorposition_35021') at 0x23d7423f160>, <NodeApply(space='sp_sandbox', external_id='sensorposition_37245') at 0x23d7423f250>, <NodeApply(space='sp_sandbox', external_id='sensorposition_77820') at 0x23d7423f340>, <NodeApply(space='sp_sandbox', external_id='sensorposition_51974') at 0x23d7423f430>, <NodeApply(space='sp_sandbox', external_id='sensorposition_78480') at 0x23d7423f520>, <NodeApply(space='sp_sandbox', external_id='sensorposition_45036') at 0x23d7423f610>, <NodeApply(space='sp_sandbox', external_id='sensorposition_96443') at 0x23d7423f700>, <NodeApply(space='sp_sandbox', external_id='sensorposition_67631') at 0x23d7423f7f0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_30048') at 0x23d7423f8e0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_51048') at 0x23d7423f9d0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_68143') at 0x23d7423fac0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_48538') at 0x23d7423fbb0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_41314') at 0x23d7423fca0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_82594') at 0x23d7423fd90>, <NodeApply(space='sp_sandbox', external_id='sensorposition_87212') at 0x23d7423fe80>, <NodeApply(space='sp_sandbox', external_id='sensorposition_1797') at 0x23d7423ff70>, <NodeApply(space='sp_sandbox', external_id='sensorposition_74977') at 0x23d742250a0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_73937') at 0x23d74225190>, <NodeApply(space='sp_sandbox', external_id='sensorposition_39335') at 0x23d74225280>, <NodeApply(space='sp_sandbox', external_id='sensorposition_88865') at 0x23d74225370>, <NodeApply(space='sp_sandbox', external_id='sensorposition_38292') at 0x23d74225460>, <NodeApply(space='sp_sandbox', external_id='sensorposition_72268') at 0x23d74225550>, <NodeApply(space='sp_sandbox', external_id='sensorposition_90783') at 0x23d74225640>, <NodeApply(space='sp_sandbox', external_id='sensorposition_51417') at 0x23d74225730>, <NodeApply(space='sp_sandbox', external_id='sensorposition_77720') at 0x23d74225820>, <NodeApply(space='sp_sandbox', external_id='sensorposition_2657') at 0x23d74225910>, <NodeApply(space='sp_sandbox', external_id='sensorposition_68378') at 0x23d74225a00>, <NodeApply(space='sp_sandbox', external_id='sensorposition_17779') at 0x23d74225af0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_51964') at 0x23d74225be0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_11942') at 0x23d74225cd0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_36163') at 0x23d74225dc0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_16439') at 0x23d74225eb0>, <NodeApply(space='sp_sandbox', external_id='sensorposition_82778') at 0x23d74225fa0>, <NodeApply(space='sp_sandbox', external_id='sensorposition
0>, <NodeApply(space='sp_sandbox', external_id='gearbox_66495') at 0x23d73e5ca90>, <NodeApply(space='sp_sandbox', external_id='gearbox_76877') at 0x23d73e5cb80>, <NodeApply(space='sp_sandbox', external_id='gearbox_31408') at 0x23d73e5cc70>, <NodeApply(space='sp_sandbox', external_id='gearbox_31861') at 0x23d73e5cd60>, <NodeApply(space='sp_sandbox', external_id='gearbox_65693') at 0x23d73e5ce50>, <NodeApply(space='sp_sandbox', external_id='gearbox_54773') at 0x23d73e5cf40>, <NodeApply(space='sp_sandbox', external_id='gearbox_45246') at 0x23d73e61070>, <NodeApply(space='sp_sandbox', external_id='gearbox_40783') at 0x23d73e61160>, <NodeApply(space='sp_sandbox', external_id='gearbox_73593') at 0x23d73e61250>, <NodeApply(space='sp_sandbox', external_id='gearbox_57953') at 0x23d73e61340>, <NodeApply(space='sp_sandbox', external_id='gearbox_94857') at 0x23d73e61430>, <NodeApply(space='sp_sandbox', external_id='gearbox_64227') at 0x23d73e61520>, <NodeApply(space='sp_sandbox', external_id='gearbox_66172') at 0x23d73e61610>, <NodeApply(space='sp_sandbox', external_id='gearbox_20800') at 0x23d73e61700>, <NodeApply(space='sp_sandbox', external_id='gearbox_74970') at 0x23d73e617f0>, <NodeApply(space='sp_sandbox', external_id='gearbox_77260') at 0x23d73e618e0>, <NodeApply(space='sp_sandbox', external_id='gearbox_46930') at 0x23d73e619d0>, <NodeApply(space='sp_sandbox', external_id='gearbox_8528') at 0x23d73e61ac0>, <NodeApply(space='sp_sandbox', external_id='gearbox_42944') at 0x23d73e61bb0>, <NodeApply(space='sp_sandbox', external_id='gearbox_67890') at 0x23d73e61ca0>, <NodeApply(space='sp_sandbox', external_id='gearbox_4845') at 0x23d73e61d90>, <NodeApply(space='sp_sandbox', external_id='gearbox_84240') at 0x23d73e61e80>, <N ...
#           ViewMockData(view_id=ViewId(space='power-models', external_id='MainShaft', version='1'), instance_space='sp_sandbox', node=[<NodeApply(space='sp_sandbox', external_id='mainshaft_18991') at 0x23d73f6bcd0>, <NodeApply(space='sp_sandbox', external_id='mainshaft_842') at 0x23d73e42460>, <NodeApply(space='sp_sandbox', external_id='mainshaft_17499') at 0x23d73f0da90>, <NodeApply(space='sp_sandbox', external_id='mainshaft_79137') at 0x23d73f0db80>, <NodeApply(space='sp_sandbox', external_id='mainshaft_54550') at 0x23d73f0dc70>, <NodeApply(space='sp_sandbox', external_id='mainshaft_60762') at 0x23d73f0dd60>, <NodeApply(space='sp_sandbox', external_id='mainshaft_39339') at 0x23d73f0de50>, <NodeApply(space='sp_sandbox', external_id='mainshaft_16375') at 0x23d73f0df40>, <NodeApply(space='sp_sandbox', external_id='mainshaft_99009') at 0x23d73f2f070>, <NodeApply(space='sp_sandbox', external_id='mainshaft_30326') at 0x23d73f2f160>, <NodeApply(space='sp_sandbox', external_id='mainshaft_5234') at 0x23d73f2f250>, <NodeApply(space='sp_sandbox', external_id='mainshaft_90151') at 0x23d73f2f340>, <NodeApply(space='sp_sandbox', external_id='mainshaft_56568') at 0x23d73f2f430>, <NodeApply(space='sp_sandbox', external_id='mainshaft_83981') at 0x23d73f2f520>, <NodeApply(space='sp_sandbox', external_id='mainshaft_47315') at 0x23d73f2f610>, <NodeApply(space='sp_sandbox', external_id='mainshaft_43666') at 0x23d73f2f700>, <NodeApply(space='sp_sandbox', external_id='mainshaft_13829') at 0x23d73f2f7f0>, <NodeApply(space='sp_sandbox', external_id='mainshaft_5274') at 0x23d73f2f8e0>, <NodeApply(space='sp_sandbox', external_id='mainshaft_65605') at 0x23d73f2f9d0>, <NodeApply(space='sp_sandbox', external_id='mainshaft_25841') at 0x23d73f2fac0>, <NodeApply(space='sp_sandbox', external_id='mainshaft_21959') at 0x23d73f2fbb0>, <NodeApply(space='sp_sandbox', external_id='mainshaft_16659') at 0x23d73f2fca0>, <NodeApply(space='sp_sandbox', external_id='mainshaft
# %% [markdown]
# ## Customized Random Generation

# %% [markdown]
# We can also control how the random data is generated.
#
# We have two interfaces:
#
# * Generation of mock data
# * Generation of node IDs

# %%
DataType
# Out:
# typing.Union[int, float, bool, str, dict, NoneType]

# %%
GeneratorFunction
# Out:
# cognite.pygen.utils.mock_generator.GeneratorFunction

# %%
IDGeneratorFunction
# Out:
# cognite.pygen.utils.mock_generator.IDGeneratorFunction

# %% [markdown]
# In the data model, there is a `Blade` view

# %%
blade = next(v for v in views if v.external_id == "Blade")

# %%
blade.dump()["properties"].keys()
# Out:
# dict_keys(['name', 'is_damaged', 'sensor_positions'])

# %% [markdown]
# We see that this view has a property `is_damaged`, we want to replace the default generation of random value for this property.
#
# We set it such that the blade is damaged in 10% of the cases

# %%
import random

# %%
blade_config = ViewMockConfig(
    properties={"is_damaged": lambda count: random.choices([True, False], weights=[0.1, 0.9], k=count)}
)

# %% [markdown]
# In addition, we want all properties of type `Text` to be a random name

# %%
from faker import Faker

# %%
from cognite.client import data_modeling as dm

# %%
# Note that since we are using an external source for the ransomness, we have to set the seed ourselves
Faker.seed(42)
faker = Faker()

# %%
default_config = ViewMockConfig(
    property_types={dm.Text: lambda count: [faker.unique.name() for _ in range(count)]}
)

# %%
custom_generator = MockGenerator(views, "sp_sandbox", view_configs={blade.as_id(): blade_config}, default_config=default_config, seed=7)

# %%
customized_mock_data = custom_generator.generate_mock_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 customized_mock_data = custom_generator.generate_mock_data()
#
# File ~\Projects\internal\pygen\cognite\pygen\utils\mock_generator.py:151, in MockGenerator.generate_mock_data(self)
#     149 mock_data = MockData()
#     150 for components in _connected_views(self._views):
# --> 151     data = self._generate_views_mock_data(components)
#     152     mock_data.extend(data)
#     153 return mock_data
#
# File ~\Projects\internal\pygen\cognite\pygen\utils\mock_generator.py:156, in MockGenerator._generate_views_mock_data(self, views)
#     155 def _generate_views_mock_data(self, views: list[dm.View]) -> MockData:
# --> 156     outputs = self._generate_mock_nodes(views)
#     157     self._generate_mock_relations(views, outputs)
#     158     return MockData(outputs.values())
#
# File ~\Projects\internal\pygen\cognite\pygen\utils\mock_generator.py:175, in MockGenerator._generate_mock_nodes(self, views)
#     173 view_id = view.as_id()
#     174 config = self._view_configs.get(view_id, self._default_config)
# --> 175 properties, external = self._generate_mock_values(mapped_properties, config, view.as_id())
#     176 node_ids = config.node_id_generator(view_id, config.node_count)
#     178 nodes = [
#     179     dm.NodeApply(
#     180         space=self._instance_space,
#    (...)
#     192     for node_id, *props in zip(node_ids, *properties.values())
#     193 ]
#
# File ~\Projects\internal\pygen\cognite\pygen\utils\mock_generator.py:287, in MockGenerator._generate_mock_values(self, properties, config, view_id)
#     285     generator = config.property_types[type(prop.type)]
#     286 else:
# --> 287     raise ValueError(f"Could not generate mock data for property {name} of type {type(prop.type)}")
#     289 null_values = int(prop.nullable and config.node_count * config.null_values)
#     290 node_count = config.node_count - null_values
#
# ValueError: Could not generate mock data for property position of type <class 'cognite.client.data_classes.data_modeling.data_types.Float64'>
