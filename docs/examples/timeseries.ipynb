# %%
import sys
from tests.constants import REPO_ROOT

# %%
sys.path.append(str(REPO_ROOT / "examples" ))

# %%
from scenario_instance.client import ScenarioInstanceClient

# %%
client = ScenarioInstanceClient.from_toml("config.toml")

# %%
client.scenario_instance.price_forecast(country_prefix="N", limit=5).plot(figsize=(15, 10))
