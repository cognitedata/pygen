# %% [markdown]
# # Writing Instances: Apply

# %% [markdown]
# We assume that you have [generated a SDK](generation.html) for the `Windmill` model and have a client ready to go.

# %% [markdown]
# The SDK generated by `SDK` supports nested upsert

# %%
import warnings
warnings.filterwarnings('ignore')
# This is just to enable improting the generated SDK from the examples folder in the pygen repository
import sys
from tests.constants import REPO_ROOT
sys.path.append(str(REPO_ROOT / "examples" ))

# %%
from windmill.client import WindmillClient

# %%
client = WindmillClient.from_toml("config.toml")

# %% [markdown]
# ## Constructing new Windmill

# %%
from cognite.client.data_classes import TimeSeries
from windmill.client.data_classes import WindmillApply, BladeApply, NacelleApply, RotorApply

# %% [markdown]
# Lets construct a new windmill with TimeSeries. Note the example below is not complete (some TimeSeries and components are missing),
# but is kept short to make it easier to grasp

# %%
new_windmill = WindmillApply(
    external_id="windmill:demo",
    capacity=10.0,
    windfarm="Fornebu",
    name="Windmill ATH",
    rotor=RotorApply(
        external_id="windmill:demo:rotor",
        rotor_speed_controller=TimeSeries(external_id="windmill:demo:rotor:speed_controller"),
        rpm_low_speed_shaft=TimeSeries(external_id="windmill:demo:rotor:rpm_low_speed_shaft"),
    ),
    nacelle=NacelleApply(
        external_id="windmill:demo:nacelle",
        acc_from_back_side_x=TimeSeries(external_id="windmill:demo:acc_from_back_side_x"),
        acc_from_back_side_y=TimeSeries(external_id="windmill:demo:acc_from_back_side_y"),
        acc_from_back_side_z=TimeSeries(external_id="windmill:demo:acc_from_back_side_z"),
    ),
    blades=[
        BladeApply(
            external_id="windmill:demo:blade1",
            is_damaged=False,
            name="Blade 1",
        ),
        BladeApply(
            external_id="windmill:demo:blade2",
            is_damaged=False,
            name="Blade 2",
        ),
        BladeApply(
            external_id="windmill:demo:blade3",
            is_damaged=True,
            name="Blade 3",
        ),
    ]
)

# %% [markdown]
# When writing nested data we can specify edges either with an external id for the end node, or another data class.
#
# The advangage of using a nested data class is that we can express edges without being explicit. In the example above, we are able to express that the blades `Blade 1-3` are connected to the windmill `windmill ATH` and that the `windmill ATH` is also linked to a nacelle and rotor.

# %% [markdown]
# ## Inspecting Resources to create

# %% [markdown]
# We can inspect the nodes, edges and other resources that will be created by using the `.to_instances_apply` on the new windmill object.

# %%
resources = new_windmill.to_instances_apply()

# %%
len(resources.nodes), len(resources.edges), len(resources.time_series)
# Out:
# (6, 3, 5)

# %%
resources.nodes
# Out:
# NodeApplyList([<NodeApply(space='windmill-instances', external_id='windmill:demo') at 0x14230d80f10>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:blade1') at 0x14231555fa0>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:blade2') at 0x14231555520>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:blade3') at 0x14231b8e400>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:nacelle') at 0x14231555130>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:rotor') at 0x14231b8e8b0>])

# %%
resources.edges
# Out:
# EdgeApplyList([<EdgeApply(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade1') at 0x14231a59e50>,
#                <EdgeApply(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade2') at 0x142315550a0>,
#                <EdgeApply(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade3') at 0x14231555c10>])

# %%
resources.time_series
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x14231555b80>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x14231555850>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x14231555e50>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x14231555880>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x14231555dc0>])

# %% [markdown]
# ## Creating new Windmill

# %%
created = client.windmill.apply(new_windmill)

# %% [markdown]
# Note that the call above created 6 nodes, 3 edges and 5 time series:

# %%
created.nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo', version=1) at 0x142324b9fd0>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade1', version=1) at 0x14232216d30>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade2', version=1) at 0x14232216e80>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade3', version=1) at 0x142322160d0>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:nacelle', version=2) at 0x14232216220>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:rotor', version=2) at 0x14231b33760>])

# %%
created.edges
# Out:
# EdgeApplyResultList([<EdgeApplyResult(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade1', version=1) at 0x14231b330a0>,
#                      <EdgeApplyResult(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade2', version=1) at 0x14231f2aa90>,
#                      <EdgeApplyResult(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade3', version=1) at 0x14231f2a8b0>])

# %% [markdown]
# And we can now see that the movie is now listed among the others.

# %%
created.time_series
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x142323effa0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x142323effd0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x142323ef0a0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x142323efd90>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x142323efac0>])

# %% [markdown]
# We can inspect the newly created windmill by calling retrieve with the external id

# %%
client.windmill.retrieve(new_windmill.external_id)
# Out:
# Windmill(space='windmill-instances', external_id='windmill:demo', version=1, last_updated_time=datetime.datetime(2023, 12, 30, 15, 6, 10, 973000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 30, 15, 6, 10, 973000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=10.0, name='Windmill ATH', windfarm='Fornebu')

# %% [markdown]
# # Deleting Instances

# %% [markdown]
# You can delete by passing and external ID or a sequence of external id to the delete method.

# %% [markdown]
# We can delete the newly created windmill

# %%
client.windmill.list()
# Out:
# WindmillList([Windmill(space='windmill-instances', external_id='hornsea_1_mill_3', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_3', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_2', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_2', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_1', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_1', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_4', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_4', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_5', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_5', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='windmill:demo', version=1, last_updated_time=datetime.datetime(2023, 12, 30, 15, 6, 10, 973000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 30, 15, 6, 10, 973000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=10.0, name='Windmill ATH', windfarm='Fornebu')])

# %%
client.windmill.delete("windmill:demo")
# Out:
# InstancesDeleteResult(nodes=[NodeId(space='windmill-instances', external_id='windmill:demo')], edges=[])

# %% [markdown]
# After the delete call the new windmill is gone

# %%
client.windmill.list()
# Out:
# WindmillList([Windmill(space='windmill-instances', external_id='hornsea_1_mill_3', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_3', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_2', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_2', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_1', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_1', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_4', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_4', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_5', version=1, last_updated_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None, capacity=7.0, name='hornsea_1_mill_5', windfarm='Hornsea 1')])

# %%
# Cleanup windmill and timeseries
cdf = client.windmill._client

cdf.data_modeling.instances.delete(nodes=created.nodes.as_ids(), edges=created.edges.as_ids());

cdf.time_series.delete(external_id=created.time_series.as_external_ids(), ignore_unknown_ids=True);
