# %% [markdown]
# # Writing Instances: Upsert

# %% [markdown]
# We assume that you have [generated a SDK](generation.html) for the `Windmill` model and have a client ready to go.

# %% [markdown]
# The SDK generated by `SDK` supports nested upsert

# %%
import warnings

warnings.filterwarnings("ignore")
# This is just to enable importing the generated SDK from the examples folder in the pygen repository
import sys  # noqa: E402

from tests.constants import REPO_ROOT  # noqa: E402

sys.path.append(str(REPO_ROOT / "examples"))

# %%
from windmill import WindmillClient

# %%
client = WindmillClient.from_toml("config.toml")

# %% [markdown]
# ## Constructing new Windmill

# %% [markdown]
# When constructing a new Windmill we need to use the generated data classes from `pygen`.
# We can import this as follows:

# %%
from cognite.client.data_classes import TimeSeries
from windmill.data_classes import BladeWrite, NacelleWrite, RotorWrite, WindmillWrite

# %% [markdown]
# The location of the data classes is determined by the parameter `top_level_package` which is set when you generate the SDK,
# either using the `generate_sdk_notebook` (simplified wrapper around) or `generate_sdk`. If you don't set it, it will be
# default set to the external_id of the data model converted to snake_case. For this example, the `external_id=Windmill`
# thus the `top_level_package = windmill`.

# %% [markdown]
# Lets construct a new windmill with TimeSeries. Note the example below is not complete (some TimeSeries and components are missing),
# but is kept short to make it easier to grasp

# %%
new_windmill = WindmillWrite(
    external_id="windmill:demo",
    capacity=10.0,
    windfarm="Fornebu",
    name="Windmill ATH",
    rotor=RotorWrite(
        external_id="windmill:demo:rotor",
        rotor_speed_controller=TimeSeries(external_id="windmill:demo:rotor:speed_controller"),
        rpm_low_speed_shaft=TimeSeries(external_id="windmill:demo:rotor:rpm_low_speed_shaft"),
    ),
    nacelle=NacelleWrite(
        external_id="windmill:demo:nacelle",
        acc_from_back_side_x=TimeSeries(external_id="windmill:demo:acc_from_back_side_x"),
        acc_from_back_side_y=TimeSeries(external_id="windmill:demo:acc_from_back_side_y"),
        acc_from_back_side_z=TimeSeries(external_id="windmill:demo:acc_from_back_side_z"),
    ),
    blades=[
        BladeWrite(
            external_id="windmill:demo:blade1",
            is_damaged=False,
            name="Blade 1",
        ),
        BladeWrite(
            external_id="windmill:demo:blade2",
            is_damaged=False,
            name="Blade 2",
        ),
        BladeWrite(
            external_id="windmill:demo:blade3",
            is_damaged=True,
            name="Blade 3",
        ),
    ],
)

# %% [markdown]
# When writing nested data we can specify edges either with an external id for the end node, or another data class.
#
# The advangage of using a nested data class is that we can express edges without being explicit. In the example above, we are able to express that the blades `Blade 1-3` are connected to the windmill `windmill ATH` and that the `windmill ATH` is also linked to a nacelle and rotor.

# %% [markdown]
# ## Inspecting Resources to create

# %% [markdown]
# We can inspect the nodes, edges and other resources that will be created by using the `.to_instances_write` on the new windmill object.

# %%
resources = new_windmill.to_instances_write()

# %%
len(resources.nodes), len(resources.edges), len(resources.time_series)
# Out:
# (6, 3, 5)

# %%
resources.nodes
# Out:
# NodeApplyList([<NodeApply(space='windmill-instances', external_id='windmill:demo') at 0x214a458dfa0>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:blade1') at 0x214be053df0>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:blade2') at 0x214be0a5d30>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:blade3') at 0x214be0a5df0>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:nacelle') at 0x214be0a5a30>,
#                <NodeApply(space='windmill-instances', external_id='windmill:demo:rotor') at 0x214be0a5f40>])

# %%
resources.edges
# Out:
# EdgeApplyList([<EdgeApply(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade1') at 0x214be053b20>,
#                <EdgeApply(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade2') at 0x214be053dc0>,
#                <EdgeApply(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade3') at 0x214be053c40>])

# %%
resources.time_series
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x214be0a50d0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be0a50a0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be0a5070>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be0a5130>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be0a5100>])

# %% [markdown]
# ## Creating new Windmill

# %% [markdown]
# **Optinal Reading**: Why `client.upsert` and not `client.windmill.upsert`?
#
# In contrast from other methods, the `.upsert` method is on the `client` instead of the individual API class. So instead of `client.windmill.upsert`, we use `client.upsert`.
#
# The reason for this is that the `new_windmill` we created above is enhanced by `pygen` with all the information needed to write it correctly to our data model. This means that all `.upsert` methods are the same, this is in contrast to methods such as `.list` and `.retrieve` which are specialized for each data type.
#
# Furthermore, the reason for not duplicating the `.upsert` methods on each API class (`client.windmill.upsert`, `client.blade.upsert`, and so on) is that encourages an anti-pattern (bad practice), in which nodes and edges are created in small batches. It is much more efficient to create all nodes and edges in as few batches as possible.

# %%
created = client.upsert(new_windmill)

# %% [markdown]
# Note that the call above created 6 nodes, 3 edges and 5 time series:

# %%
created.nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo', version=1) at 0x214be088490>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade1', version=1) at 0x214be088be0>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade2', version=1) at 0x214be088cd0>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade3', version=1) at 0x214be088c40>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:nacelle', version=2) at 0x214be088160>,
#                      <NodeApplyResult(space='windmill-instances', external_id='windmill:demo:rotor', version=2) at 0x214be088730>])

# %%
created.edges
# Out:
# EdgeApplyResultList([<EdgeApplyResult(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade1', version=1) at 0x214be088190>,
#                      <EdgeApplyResult(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade2', version=1) at 0x214be088ca0>,
#                      <EdgeApplyResult(space='windmill-instances', external_id='windmill:demo:windmill:demo:blade3', version=1) at 0x214be088f10>])

# %%
created.time_series
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x214be11f100>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be11f520>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be11fd60>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be11fd90>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x214be11fca0>])

# %% [markdown]
# We can inspect the newly created windmill by calling retrieve with the external id

# %%
client.windmill.retrieve(new_windmill.external_id)
# Out:
# Windmill(space='windmill-instances', external_id='windmill:demo', data_record=DataRecord(version=1, last_updated_time=datetime.datetime(2024, 3, 9, 7, 46, 38, 476000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 3, 9, 7, 46, 38, 476000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=10.0, name='Windmill ATH', windfarm='Fornebu')

# %% [markdown]
# ## Upsert Parameters <code>replace</code>, <code>write_none</code>, and <code>allow_version_increase</code>

# %% [markdown]
# The upsert method have several parameters that control how the upsert call should be done. In this section, we will go through each of these flags.

# %% [markdown]
# ### Parameter: <code>replace</code>

# %% [markdown]
# The `replace` flag decide what to do if the item we are upserting already exists. If `replace` is set to `True` all properties of the existing item will be replaced by the properties set in the upsert call,
# and the properties not included will be to null. If `replace` is set to `False`, then only the properties included in the upsert call will be updated.
#
# Let's demonstrate this by creating a new blade and update it. We start by creating a new blade and call upsert on it.
#
# A blade has two properties: `name` and `is_damaged`. In addition, it has edges to the `sensor_positions` connected to the blade. In this example, we will focus on the two properties, which are both nullable, meaning that they are optional.

# %%
from windmill.data_classes import BladeWrite

# %%
new_blade = BladeWrite(
    external_id="windmill:demo:blade4",
    name="Demo Blade",
)

# %%
created_blade = client.upsert(new_blade)

# %%
created_blade.nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade4', version=1) at 0x214be088fd0>])

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)

# %%
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:blade4', data_record=DataRecord(version=1, last_updated_time=datetime.datetime(2024, 5, 27, 11, 44, 45, 552000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 5, 27, 11, 44, 45, 552000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=None, name='Demo Blade')

# %% [markdown]
# We can see that the `is_damaged` property is not set, while we have the `name` property set. We will now update the blade with the `is_damaged` property set to `True`.

# %%
updated_blade = BladeWrite(
    external_id="windmill:demo:blade4",
    is_damaged=True,
)

# %%
update = client.upsert(updated_blade, replace=False)

# %%
update.nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade4', version=2) at 0x214be16ee50>])

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)

# %%
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:blade4', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 5, 27, 11, 44, 48, 336000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 5, 27, 11, 44, 45, 552000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=True, name='Demo Blade')

# %% [markdown]
# We see that the blade property `is_damaged` is now set to `True`, while the `name` property is unchanged. This is because we set `replace` to `False`. If we set `replace` to `True`, then the `name` property would be set to `null`. Let's create a new update were we set the `is_damaged` property to `False` and use `replace` set to `True`.

# %%
blade_update2 = BladeWrite(
    external_id="windmill:demo:blade4",
    is_damaged=False,
)

# %%
update2 = client.upsert(blade_update2, replace=True)

# %%
update2.nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:blade4', version=3) at 0x214be17da30>])

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)

# %%
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:blade4', data_record=DataRecord(version=3, last_updated_time=datetime.datetime(2024, 5, 27, 11, 44, 52, 605000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 5, 27, 11, 44, 45, 552000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=False, name=None)

# %% [markdown]
# Notice that the `name` property is now set to `null` as we set `replace` to `True`.

# %%
# Cleanup
client.delete("windmill:demo:blade4")
# Out:
# InstancesDeleteResult(nodes=[NodeId(space='windmill-instances', external_id='windmill:demo:blade4')], edges=[])

# %% [markdown]
# ### Parameter: <code>write_none</code>

# %% [markdown]
# By default, when calling `.upsert` properties which are set to `None` are not sent to the server. This is because we interpret `None` as "skip this property". If you want to set a property to `null` you can use the `write_none` flag.
#
# Let's demonstrate this by creating a new blade with the `is_damaged` property set to `True`, and then update it to be not set.

# %%
from windmill.data_classes import BladeWrite

# %%
new_blade = BladeWrite(external_id="windmill:demo:write_none", name="Demo Blade", is_damaged=True)

# %%
client.upsert(new_blade).nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:write_none', version=1) at 0x214be0a5640>])

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:write_none', data_record=DataRecord(version=1, last_updated_time=datetime.datetime(2024, 5, 27, 11, 45, 0, 788000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 5, 27, 11, 45, 0, 788000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=True, name='Demo Blade')

# %%
updated_blade = BladeWrite(
    external_id="windmill:demo:write_none",
    is_damaged=None,
)

# %%
client.upsert(updated_blade, write_none=False).nodes
# Out:
# NodeApplyResultList([])

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:write_none', data_record=DataRecord(version=1, last_updated_time=datetime.datetime(2024, 5, 27, 11, 45, 0, 788000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 5, 27, 11, 45, 0, 788000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=True, name='Demo Blade')

# %% [markdown]
# We see that when we set the `is_damaged` property to `None` it is not sent to the server. If we set `write_none` to `True` then the `is_damaged` property would be set to `null`.

# %%
client.upsert(updated_blade, write_none=True).nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:write_none', version=2) at 0x214be088880>])

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:write_none', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 5, 27, 11, 45, 7, 423000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 5, 27, 11, 45, 0, 788000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=None, name=None)

# %% [markdown]
# Notice that the `is_damaged` property is now set to `null` as well as the `name` property as now all properties are explicitly set to `null` in the upsert call.

# %%
# Cleanup
client.delete("windmill:demo:write_none")
# Out:
# InstancesDeleteResult(nodes=[NodeId(space='windmill-instances', external_id='windmill:demo:write_none')], edges=[])

# %% [markdown]
# ### Parameter: <code>allow_version_increase</code>

# %% [markdown]
# If you notice in the last examples, that when updating the blade, the version of the returning node is increasing. This is because each time we do a change to the blade node it is registered and the version is increased. You can control this behavior by setting the `existing_version` property in `data_record` of the blade node. Let's demonstrate with an example

# %%
from windmill.data_classes import BladeWrite, DataRecordWrite

# %%
new_blade = BladeWrite(external_id="windmill:demo:allow_version_increase", name="Demo Blade", is_damaged=True)

# %%
client.upsert(new_blade).nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:allow_version_increase', version=3) at 0x214be11f8b0>])

# %% [markdown]
# We see that we have version 1 of the blade. If we want to avoid overwriting this blade by accident, we can set the `existing_version` property to lower than the version we want to avoid overwriting in the `data_record` of the blade node. This will be `0` in this case.

# %%
new_blade2 = BladeWrite(
    external_id="windmill:demo:allow_version_increase",
    name="Demo Blade",
    is_damaged=False,
    data_record=DataRecordWrite(existing_version=0),
)

# %%
client.upsert(new_blade2).nodes
# Out:
# ---------------------------------------------------------------------------
# CogniteAPIError                           Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 client.upsert(new_blade2).nodes
#
# File ~\Projects\internal\pygen\examples\windmill\_api_client.py:103, in WindmillClient.upsert(self, items, replace, write_none, allow_version_increase)
#      87 """Add or update (upsert) items.
#      88
#      89 Args:
#    (...)
#     100
#     101 """
#     102 instances = self._create_instances(items, write_none, allow_version_increase)
# --> 103 result = self._client.data_modeling.instances.apply(
#     104     nodes=instances.nodes,
#     105     edges=instances.edges,
#     106     auto_create_start_nodes=True,
#     107     auto_create_end_nodes=True,
#     108     replace=replace,
#     109 )
#     110 time_series = []
#     111 if instances.time_series:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\_api\data_modeling\instances.py:655, in InstancesAPI.apply(self, nodes, edges, auto_create_start_nodes, auto_create_end_nodes, auto_create_direct_relations, skip_on_version_conflict, replace)
#     652 edges = edges or []
#     653 edges = edges if isinstance(edges, Sequence) else [edges]
# --> 655 res = self._create_multiple(
#     656     items=cast(Sequence[WriteableCogniteResource], (*nodes, *edges)),
#     657     list_cls=_NodeOrEdgeApplyResultList,
#     658     resource_cls=_NodeOrEdgeApplyResultAdapter,  # type: ignore[type-var]
#     659     extra_body_fields=other_parameters,
#     660     input_resource_cls=_NodeOrEdgeApplyAdapter,  # type: ignore[arg-type]
#     661     executor=ConcurrencySettings.get_data_modeling_executor(),
#     662 )
#     663 return InstancesApplyResult(
#     664     nodes=NodeApplyResultList([item for item in res if isinstance(item, NodeApplyResult)]),
#     665     edges=EdgeApplyResultList([item for item in res if isinstance(item, EdgeApplyResult)]),
#     666 )
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\_api_client.py:843, in APIClient._create_multiple(self, items, list_cls, resource_cls, resource_path, params, headers, extra_body_fields, limit, input_resource_cls, executor, api_subversion)
#     840         return dumped
#     841     return el
# --> 843 summary.raise_compound_exception_if_failed_tasks(
#     844     task_unwrap_fn=lambda task: task[1]["items"],
#     845     task_list_element_unwrap_fn=unwrap_element,
#     846     str_format_element_fn=str_format_element,
#     847 )
#     848 created_resources = summary.joined_results(lambda res: res.json()["items"])
#     850 if single_item:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\utils\_concurrency.py:74, in TasksSummary.raise_compound_exception_if_failed_tasks(self, task_unwrap_fn, task_list_element_unwrap_fn, str_format_element_fn)
#      72 task_lists = dict(successful=successful, failed=failed, unknown=unknown, skipped=skipped)
#      73 if self.unknown_error:
# ---> 74     self._raise_basic_api_error(str_format_element_fn, **task_lists)
#      75 if self.not_found_error:
#      76     self._raise_not_found_error(str_format_element_fn, **task_lists)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\utils\_concurrency.py:100, in TasksSummary._raise_basic_api_error(self, unwrap_fn, **task_lists)
#      98 def _raise_basic_api_error(self, unwrap_fn: Callable, **task_lists: list) -> NoReturn:
#      99     if isinstance(self.unknown_error, CogniteAPIError) and (task_lists["failed"] or task_lists["unknown"]):
# --> 100         raise CogniteAPIError(
#     101             message=self.unknown_error.message,
#     102             code=self.unknown_error.code,
#     103             x_request_id=self.unknown_error.x_request_id,
#     104             missing=self.missing,
#     105             duplicated=self.duplicated,
#     106             extra=self.unknown_error.extra,
#     107             unwrap_fn=unwrap_fn,
#     108             **task_lists,
#     109         )
#     110     raise self.unknown_error
#
# CogniteAPIError: A version conflict caused the ingest to fail. | code: 409 | X-Request-ID: 9fbf6f19-0feb-9dec-ae90-781af1de13bc
# The API Failed to process some items.
# Successful (2xx): []
# Unknown (5xx): []
# Failed (4xx): [windmill-instances:windmill:demo:allow_version_increase, ...]
# Additional error info: {
#     "isAutoRetryable": false
# }

# %% [markdown]
# This can cause problems when we want to migrate data from one project to another, or from one data model to another. It is a common pattern that we use the `pygen` generated SDK to retrieve from one project and then use the `.as_write` method to turn the retrieved read format of a node into the write format. We want to ensure we always will overwrite the nodes in the new project. Then, we can use the `allow_version_increase` flag to ensure that we always overwrite the all the nodes and edges we are writing will have set `existing_version` to `None` which will ensure that we always overwrite the nodes and edges.

# %%
retrieved_blade = client.blade.retrieve(new_blade.external_id)
retrieved_blade
# Out:
# Blade(space='windmill-instances', external_id='windmill:demo:allow_version_increase', data_record=DataRecord(version=3, last_updated_time=datetime.datetime(2024, 3, 9, 8, 45, 12, 212000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 3, 9, 8, 43, 35, 316000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, is_damaged=True, name='Demo Blade')

# %%
client.upsert(BladeWrite(external_id="windmill:demo:allow_version_increase", name="Updated", is_damaged=True)).nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:allow_version_increase', version=4) at 0x214be088f40>])

# %%
writeable_blade = retrieved_blade.as_write()

# %%
writeable_blade
# Out:
# BladeWrite(space='windmill-instances', external_id='windmill:demo:allow_version_increase', data_record=DataRecordWrite(existing_version=3), node_type=None, is_damaged=True, name='Demo Blade')

# %%
client.upsert(writeable_blade).nodes
# Out:
# ---------------------------------------------------------------------------
# CogniteAPIError                           Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 client.upsert(writeable_blade).nodes
#
# File ~\Projects\internal\pygen\examples\windmill\_api_client.py:103, in WindmillClient.upsert(self, items, replace, write_none, allow_version_increase)
#      87 """Add or update (upsert) items.
#      88
#      89 Args:
#    (...)
#     100
#     101 """
#     102 instances = self._create_instances(items, write_none, allow_version_increase)
# --> 103 result = self._client.data_modeling.instances.apply(
#     104     nodes=instances.nodes,
#     105     edges=instances.edges,
#     106     auto_create_start_nodes=True,
#     107     auto_create_end_nodes=True,
#     108     replace=replace,
#     109 )
#     110 time_series = []
#     111 if instances.time_series:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\_api\data_modeling\instances.py:655, in InstancesAPI.apply(self, nodes, edges, auto_create_start_nodes, auto_create_end_nodes, auto_create_direct_relations, skip_on_version_conflict, replace)
#     652 edges = edges or []
#     653 edges = edges if isinstance(edges, Sequence) else [edges]
# --> 655 res = self._create_multiple(
#     656     items=cast(Sequence[WriteableCogniteResource], (*nodes, *edges)),
#     657     list_cls=_NodeOrEdgeApplyResultList,
#     658     resource_cls=_NodeOrEdgeApplyResultAdapter,  # type: ignore[type-var]
#     659     extra_body_fields=other_parameters,
#     660     input_resource_cls=_NodeOrEdgeApplyAdapter,  # type: ignore[arg-type]
#     661     executor=ConcurrencySettings.get_data_modeling_executor(),
#     662 )
#     663 return InstancesApplyResult(
#     664     nodes=NodeApplyResultList([item for item in res if isinstance(item, NodeApplyResult)]),
#     665     edges=EdgeApplyResultList([item for item in res if isinstance(item, EdgeApplyResult)]),
#     666 )
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\_api_client.py:843, in APIClient._create_multiple(self, items, list_cls, resource_cls, resource_path, params, headers, extra_body_fields, limit, input_resource_cls, executor, api_subversion)
#     840         return dumped
#     841     return el
# --> 843 summary.raise_compound_exception_if_failed_tasks(
#     844     task_unwrap_fn=lambda task: task[1]["items"],
#     845     task_list_element_unwrap_fn=unwrap_element,
#     846     str_format_element_fn=str_format_element,
#     847 )
#     848 created_resources = summary.joined_results(lambda res: res.json()["items"])
#     850 if single_item:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\utils\_concurrency.py:74, in TasksSummary.raise_compound_exception_if_failed_tasks(self, task_unwrap_fn, task_list_element_unwrap_fn, str_format_element_fn)
#      72 task_lists = dict(successful=successful, failed=failed, unknown=unknown, skipped=skipped)
#      73 if self.unknown_error:
# ---> 74     self._raise_basic_api_error(str_format_element_fn, **task_lists)
#      75 if self.not_found_error:
#      76     self._raise_not_found_error(str_format_element_fn, **task_lists)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\cognite-pygen-9ATJrLbx-py3.9\lib\site-packages\cognite\client\utils\_concurrency.py:100, in TasksSummary._raise_basic_api_error(self, unwrap_fn, **task_lists)
#      98 def _raise_basic_api_error(self, unwrap_fn: Callable, **task_lists: list) -> NoReturn:
#      99     if isinstance(self.unknown_error, CogniteAPIError) and (task_lists["failed"] or task_lists["unknown"]):
# --> 100         raise CogniteAPIError(
#     101             message=self.unknown_error.message,
#     102             code=self.unknown_error.code,
#     103             x_request_id=self.unknown_error.x_request_id,
#     104             missing=self.missing,
#     105             duplicated=self.duplicated,
#     106             extra=self.unknown_error.extra,
#     107             unwrap_fn=unwrap_fn,
#     108             **task_lists,
#     109         )
#     110     raise self.unknown_error
#
# CogniteAPIError: A version conflict caused the ingest to fail. | code: 409 | X-Request-ID: b319ba8e-bdaa-9705-a2cc-48428aa1762a
# The API Failed to process some items.
# Successful (2xx): []
# Unknown (5xx): []
# Failed (4xx): [windmill-instances:windmill:demo:allow_version_increase, ...]
# Additional error info: {
#     "isAutoRetryable": false
# }

# %%
client.upsert(writeable_blade, allow_version_increase=True).nodes
# Out:
# NodeApplyResultList([<NodeApplyResult(space='windmill-instances', external_id='windmill:demo:allow_version_increase', version=5) at 0x214be947c10>])

# %% [markdown]
# We see that the `allow_version_increase` flag ensures that we always overwrite the nodes and edges.

# %%
# Cleanup
client.delete("windmill:demo:allow_version_increase")
# Out:
# InstancesDeleteResult(nodes=[NodeId(space='windmill-instances', external_id='windmill:demo:allow_version_increase')], edges=[])

# %% [markdown]
# ## Creating from <code>JSON</code> Format

# %% [markdown]
# See the quick start guide [data population](../quickstart/ingestion.html) for an example of creating instances from `JSON`.

# %% [markdown]
# # Deleting Instances

# %% [markdown]
# You can delete by passing and external ID or an Item or a sequence of external id or items to the delete method.

# %% [markdown]
# We can delete the newly created windmill

# %%
client.windmill.list()
# Out:
# WindmillList([Windmill(space='windmill-instances', external_id='hornsea_1_mill_3', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_3', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_2', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_2', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_1', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_1', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_4', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_4', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_5', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_5', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='windmill:demo', data_record=DataRecord(version=1, last_updated_time=datetime.datetime(2024, 3, 9, 7, 46, 38, 476000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2024, 3, 9, 7, 46, 38, 476000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=10.0, name='Windmill ATH', windfarm='Fornebu')])

# %% [markdown]
# Same as `.upsert`, the delete method is located on the client and not the API class.

# %%
deleted = client.delete(new_windmill)

# %%
len(deleted.nodes), len(deleted.edges)
# Out:
# (6, 3)

# %% [markdown]
# After the delete call the new windmill is gone

# %%
client.windmill.list()
# Out:
# WindmillList([Windmill(space='windmill-instances', external_id='hornsea_1_mill_3', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_3', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_2', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_2', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_1', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_1', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_4', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_4', windfarm='Hornsea 1'),
#               Windmill(space='windmill-instances', external_id='hornsea_1_mill_5', data_record=DataRecord(version=2, last_updated_time=datetime.datetime(2024, 2, 10, 9, 30, 16, 893000, tzinfo=TzInfo(UTC)), created_time=datetime.datetime(2023, 12, 25, 7, 47, 50, 40000, tzinfo=TzInfo(UTC)), deleted_time=None), node_type=None, capacity=7.0, name='hornsea_1_mill_5', windfarm='Hornsea 1')])

# %% [markdown]
# In addition, since we passed in the entire object and not just an external ID, all the edges and nodes connected to the `windmill:demo` was also deleted.

# %%
# Cleanup windmill and timeseries
cdf = client.windmill._client

cdf.data_modeling.instances.delete(nodes=created.nodes.as_ids(), edges=created.edges.as_ids())

cdf.time_series.delete(external_id=created.time_series.as_external_ids(), ignore_unknown_ids=True);
